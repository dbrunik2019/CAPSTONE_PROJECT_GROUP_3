# %%
#dependencies 

import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('BJCP_STYLE.CSV')
df.head()
# Out:
#   cat subcat                    STYLE:  \
# 0   1      A      AMERICAN LIGHT LAGER
# 1   1      B            AMERICAN LAGER
# 2   1      C                 CREAM ALE
# 3   1      D       AMERICAN WHEAT BEER
# 4   2      A  INTERNATIONAL PALE LAGER
#
#                                            EXAMPLES:
# 0  Bud Light, Coors Light, Keystone Light, Michel...
# 1  Budweiser, Coors Original, Grain Belt Premium ...
# 2  Genesee Cream Ale, Liebotschaner Cream Ale, Li...
# 3  Bell’s Oberon, Boulevard Unfiltered Wheat Beer...
# 4  Asahi Super Dry, Birra Moretti, Corona Extra, ...

# %%
df1 = pd.read_csv('guidelines.csv')
df1.head()
# Out:
#      #         BJCP Categories                    Styles Style Family  \
# 0  01A  Standard American Beer      American Light Lager   Pale Lager
# 1  01B  Standard American Beer            American Lager   Pale Lager
# 2  01C  Standard American Beer                 Cream Ale     Pale Ale
# 3  01D  Standard American Beer       American Wheat Beer   Wheat Beer
# 4  02A     International Lager  International Pale Lager   Pale Lager
#
#               Style History         Origin ABV min ABV max IBUs min IBUs max  \
# 0    Mass Market Pale Lager  United States     2.8     4.2        8       12
# 1    Mass Market Pale Lager  United States     4.2     5.3        8       18
# 2  Indigenous American Beer  United States     4.2     5.6        8       20
# 3                Wheat Beer  United States       4     5.5       15       30
# 4    Mass Market Pale Lager  International     4.6       6       18       25
#
#    ...                                          Mouthfell  \
# ...

# %%
df3 = pd.read_csv('classic.csv')
df3.head()
# Out:
#   2015 Order 2008 Order 2004Order            Name    Company  2008Cat  \
# 0          1          5         2       Bud Light  Budweiser      1.0
# 1          2          6         3     Coors Light      Coors      1.0
# 2          3        ADD       NaN  Keystone Light   Keystone      NaN
# 3          4        ADD       NaN  Michelob Light   Michelob      NaN
# 4          5          4         1     Miller Lite     Miller      1.0
#
#    2008CatName 2008Sub           2008SubName  2015 Cat  \
# 0  Light Lager       A  Light American Lager       1.0
# 1  Light Lager       A  Light American Lager       1.0
# 2          NaN     NaN                   NaN       1.0
# 3          NaN     NaN                   NaN       1.0
# 4  Light Lager       A  Light American Lager       1.0
#
#               2015CatName 2015 Sub           2015SubName  2015 Sort  Date  \
# 0  Standard American Beer        A  American Light Lager        1.0  2004
# ...
