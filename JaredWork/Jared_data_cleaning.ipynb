# %%
#dependencies 

import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
recipes_df = pd.read_csv('recipeData.csv', encoding='latin-1')
recipes_df.head()
# Out:
#    BeerID                             Name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  URL  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 Style  StyleID  Size(L)     OG     FG   ABV  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American IPA        7    18.93  1.063  1.018  5.91
# 3                        American IPA        7    22.71  1.061  1.017  5.80
# 4                   Belgian Blond Ale       20    50.00  1.060  1.010  6.48
#
#      IBU  ...  BoilTime  BoilGravity  Efficiency  MashThickness  \
# 0  17.65  ...        75        1.038        70.0            NaN
# 1  60.65  ...        60        1.070        70.0            NaN
# 2  59.25  ...        60          NaN        70.0            NaN
# 3  54.48  ...        60          NaN        70.0            NaN
# 4  17.84  ...        90        1.050        72.0            NaN
#
#          SugarScale  BrewMethod PitchRate PrimaryTemp  PrimingMethod  \
# 0  Specific Gravity   All Grain       NaN       17.78     corn sugar
# 1  Specific Gravity   All Grain       NaN         NaN            NaN
# 2  Specific Gravity     extract       NaN         NaN            NaN
# 3  Specific Gravity   All Grain       NaN         NaN            NaN
# 4  Specific Gravity   All Grain       NaN       19.00     Sukkerlake
#
#     PrimingAmount
# 0          4.5 oz
# 1             NaN
# 2             NaN
# 3             NaN
# 4  6-7 g sukker/l
#
# [5 rows x 22 columns]

# %%
recipes_df.describe
# Out:
# <bound method NDFrame.describe of        BeerID                             Name  \
# 0           1                Vanilla Cream Ale
# 1           2      Southern Tier Pumking clone
# 2           3      Zombie Dust Clone - EXTRACT
# 3           4    Zombie Dust Clone - ALL GRAIN
# 4           5  Bakke Brygg Belgisk Blonde 50 l
# ...       ...                              ...
# 73856   73857                    Amber Alfie 2
# 73857   73858                          Rye IPA
# 73858   73859                        SK-Kölsch
# 73859   73860                  Flata Rødkløver
# 73860   73861            Elvis Juice IPA Clone
#
#                                                      URL  \
# 0           /homebrew/recipe/view/1633/vanilla-cream-ale
# 1      /homebrew/recipe/view/16367/southern-tier-pumk...
# 2      /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3      /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4      /homebrew/recipe/view/89534/bakke-brygg-belgis...
# ...                                                  ...
# 73856         /homebrew/recipe/view/609673/amber-alfie-2
# 73857               /homebrew/recipe/view/610955/rye-ipa
# 73858                      /homebrew/recipe/view/586891/
# 73859                      /homebrew/recipe/view/603788/
# 73860  /homebrew/recipe/view/613776/elvis-juice-ipa-c...
#
#                                     Style  StyleID  Size(L)     OG     FG  \
# 0                               Cream Ale       45    21.77  1.055  1.013
# 1      Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021
# 2                            American IPA        7    18.93  1.063  1.018
# 3                            American IPA        7    22.71  1.061  1.017
# 4                       Belgian Blond Ale       20    50.00  1.060  1.010
# ...                                   ...      ...      ...    ...    ...
# 73856                  British Strong Ale       36    21.00  1.052  1.012
# 73857              Specialty IPA: Rye IPA      151    10.00  1.059  1.010
# 73858                                 NaN      111    16.00  1.046  1.008
# 73859                       Irish Red Ale       92    24.00  1.051  1.014
# 73860                        American IPA        7    20.00  1.060  1.010
#
#         ABV    IBU  ...  BoilTime  BoilGravity  Efficiency  MashThickness  \
# 0      5.48  17.65  ...        75        1.038        70.0            NaN
# 1      8.16  60.65  ...        60        1.070        70.0            NaN
# 2      5.91  59.25  ...        60          NaN        70.0            NaN
# 3      5.80  54.48  ...        60          NaN        70.0            NaN
# 4      6.48  17.84  ...        90        1.050        72.0            NaN
# ...     ...    ...  ...       ...          ...         ...            ...
# 73856  5.22  39.73  ...        60        1.060        63.0            3.0
# 73857  6.37  59.21  ...        60        1.034        60.0            NaN
# 73858  5.01  25.42  ...        90        1.041        65.0            NaN
# 73859  4.82  25.65  ...        60        1.043        72.0            NaN
# 73860  6.55  57.09  ...        60        1.056        70.0            NaN
#
#              SugarScale    BrewMethod PitchRate PrimaryTemp  PrimingMethod  \
# 0      Specific Gravity     All Grain       NaN       17.78     corn sugar
# 1      Specific Gravity     All Grain       NaN         NaN            NaN
# 2      Specific Gravity       extract       NaN         NaN            NaN
# 3      Specific Gravity     All Grain       NaN         NaN            NaN
# 4      Specific Gravity     All Grain       NaN       19.00     Sukkerlake
# ...                 ...           ...       ...         ...            ...
# 73856  Specific Gravity     All Grain      1.25       20.00            NaN
# 73857  Specific Gravity          BIAB      0.50       22.00            NaN
# 73858  Specific Gravity          BIAB      0.35       17.00        sucrose
# 73859  Specific Gravity     All Grain       NaN       18.00     Sukkerlake
# 73860  Specific Gravity  Partial Mash       NaN       18.00            NaN
#
#         PrimingAmount
# 0              4.5 oz
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4      6-7 g sukker/l
# ...               ...
# 73856             NaN
# 73857             NaN
# 73858           140 g
# 73859    5 g sukker/l
# 73860             NaN
#
# [73861 rows x 22 columns]>

# %%
# Drop columns we don't need
recipes_df.drop(columns=["Name", "URL", "Size(L)", "BoilSize", "BoilTime", "BoilGravity", "Efficiency", "MashThickness", "PitchRate", "PrimaryTemp", "PrimingMethod", "PrimingAmount"], inplace=True)
recipes_df.head()
# Out:
#    BeerID                               Style  StyleID     OG     FG   ABV  \
# 0       1                           Cream Ale       45  1.055  1.013  5.48
# 1       2  Holiday/Winter Special Spiced Beer       85  1.083  1.021  8.16
# 2       3                        American IPA        7  1.063  1.018  5.91
# 3       4                        American IPA        7  1.061  1.017  5.80
# 4       5                   Belgian Blond Ale       20  1.060  1.010  6.48
#
#      IBU  Color        SugarScale BrewMethod
# 0  17.65   4.83  Specific Gravity  All Grain
# 1  60.65  15.64  Specific Gravity  All Grain
# 2  59.25   8.98  Specific Gravity    extract
# 3  54.48   8.50  Specific Gravity  All Grain
# 4  17.84   4.57  Specific Gravity  All Grain

# %%
new_columns_recipes_df = recipes_df

# %%
# Drop the null columns where all values are null
new_columns_recipes_df.dropna(axis='columns', how='all')
new_columns_recipes_df.describe
# Out:
# <bound method NDFrame.describe of        BeerID                               Style  StyleID     OG     FG  \
# 0           1                           Cream Ale       45  1.055  1.013
# 1           2  Holiday/Winter Special Spiced Beer       85  1.083  1.021
# 2           3                        American IPA        7  1.063  1.018
# 3           4                        American IPA        7  1.061  1.017
# 4           5                   Belgian Blond Ale       20  1.060  1.010
# ...       ...                                 ...      ...    ...    ...
# 73856   73857                  British Strong Ale       36  1.052  1.012
# 73857   73858              Specialty IPA: Rye IPA      151  1.059  1.010
# 73858   73859                                 NaN      111  1.046  1.008
# 73859   73860                       Irish Red Ale       92  1.051  1.014
# 73860   73861                        American IPA        7  1.060  1.010
#
#         ABV    IBU  Color        SugarScale    BrewMethod
# 0      5.48  17.65   4.83  Specific Gravity     All Grain
# 1      8.16  60.65  15.64  Specific Gravity     All Grain
# 2      5.91  59.25   8.98  Specific Gravity       extract
# 3      5.80  54.48   8.50  Specific Gravity     All Grain
# 4      6.48  17.84   4.57  Specific Gravity     All Grain
# ...     ...    ...    ...               ...           ...
# 73856  5.22  39.73   6.96  Specific Gravity     All Grain
# 73857  6.37  59.21   7.90  Specific Gravity          BIAB
# 73858  5.01  25.42   3.63  Specific Gravity          BIAB
# 73859  4.82  25.65  14.12  Specific Gravity     All Grain
# 73860  6.55  57.09   8.65  Specific Gravity  Partial Mash
#
# [73861 rows x 10 columns]>

# %%
# Drop the null rows
new_columns_recipes_df.dropna()
new_columns_recipes_df.describe
# Out:
# <bound method NDFrame.describe of        BeerID                               Style  StyleID     OG     FG  \
# 0           1                           Cream Ale       45  1.055  1.013
# 1           2  Holiday/Winter Special Spiced Beer       85  1.083  1.021
# 2           3                        American IPA        7  1.063  1.018
# 3           4                        American IPA        7  1.061  1.017
# 4           5                   Belgian Blond Ale       20  1.060  1.010
# ...       ...                                 ...      ...    ...    ...
# 73856   73857                  British Strong Ale       36  1.052  1.012
# 73857   73858              Specialty IPA: Rye IPA      151  1.059  1.010
# 73858   73859                                 NaN      111  1.046  1.008
# 73859   73860                       Irish Red Ale       92  1.051  1.014
# 73860   73861                        American IPA        7  1.060  1.010
#
#         ABV    IBU  Color        SugarScale    BrewMethod
# 0      5.48  17.65   4.83  Specific Gravity     All Grain
# 1      8.16  60.65  15.64  Specific Gravity     All Grain
# 2      5.91  59.25   8.98  Specific Gravity       extract
# 3      5.80  54.48   8.50  Specific Gravity     All Grain
# 4      6.48  17.84   4.57  Specific Gravity     All Grain
# ...     ...    ...    ...               ...           ...
# 73856  5.22  39.73   6.96  Specific Gravity     All Grain
# 73857  6.37  59.21   7.90  Specific Gravity          BIAB
# 73858  5.01  25.42   3.63  Specific Gravity          BIAB
# 73859  4.82  25.65  14.12  Specific Gravity     All Grain
# 73860  6.55  57.09   8.65  Specific Gravity  Partial Mash
#
# [73861 rows x 10 columns]>

# %%
new_columns_recipes_df.dtypes
# Out:
# BeerID          int64
# Style          object
# StyleID         int64
# OG            float64
# FG            float64
# ABV           float64
# IBU           float64
# Color         float64
# SugarScale     object
# BrewMethod     object
# dtype: object

# %%
# Within the SugarScale column, remove any rows that have the word "Plato" in the SugarScale column.

# %%
# Resource #2

# %%
guidelines_df = pd.read_csv('guidelines.csv')
guidelines_df.head()
# Out:
#      #         BJCP Categories                    Styles Style Family  \
# 0  01A  Standard American Beer      American Light Lager   Pale Lager
# 1  01B  Standard American Beer            American Lager   Pale Lager
# 2  01C  Standard American Beer                 Cream Ale     Pale Ale
# 3  01D  Standard American Beer       American Wheat Beer   Wheat Beer
# 4  02A     International Lager  International Pale Lager   Pale Lager
#
#               Style History         Origin ABV min ABV max IBUs min IBUs max  \
# 0    Mass Market Pale Lager  United States     2.8     4.2        8       12
# 1    Mass Market Pale Lager  United States     4.2     5.3        8       18
# 2  Indigenous American Beer  United States     4.2     5.6        8       20
# 3                Wheat Beer  United States       4     5.5       15       30
# 4    Mass Market Pale Lager  International     4.6       6       18       25
#
#    ...                                          Mouthfeel  \
# 0  ...  Very light (sometimes watery) body. Very highl...
# 1  ...  Low to medium-low body. Very highly carbonated...
# 2  ...  Generally light and crisp, although body can r...
# 3  ...  Medium-light to medium body. Medium-high to hi...
# 4  ...  Light to medium body. Moderately high to highl...
#
#                                             Comments  \
# 0  Designed to appeal to as broad a range of the ...
# 1  Strong flavors are a fault. Often what non-cra...
# 2  Pre-prohibition Cream Ales were slightly stron...
# 3  Different variations exist, from an easy-drink...
# 4  International lagers tend to have fewer adjunc...
#
#                                              History  \
# 0  Coors briefly made a light lager in the early ...
# 1  Although German immigrants had brewed traditio...
# 2  A sparkling or present-use ale that existed in...
# 3  An American craft beer adaptation of the Germa...
# 4  In the United States, developed as a premium v...
#
#                           Characteristic Ingredients  \
# 0  Two- or six-row barley with high percentage (u...
# 1  Two- or six-row barley with high percentage (u...
# 2  American ingredients most commonly used. A gra...
# 3  Clean American ale or lager yeast (German weis...
# 4  Two- or six-row barley. May use rice, corn, or...
#
#                                     Style Comparison  \
# 0  A lighter-bodied, lower-alcohol, lower calorie...
# 1  Stronger, more flavor and body than a Light Am...
# 2  Similar to a Standard American Lager, but with...
# 3  More hop character and less yeast character th...
# 4  Generally more bitter and filling than America...
#
#                                  Commercial Examples Notes Unnamed: 27  \
# 0  Bud Light, Coors Light, Keystone Light, Michel...   NaN         NaN
# 1  Budweiser, Coors Original, Grain Belt Premium ...   NaN         NaN
# 2  Genesee Cream Ale, Liebotschaner Cream Ale, Li...   NaN         NaN
# 3  Bell’s Oberon, Boulevard Unfiltered Wheat Beer...   NaN         NaN
# 4  Asahi Super Dry, Birra Moretti, Corona Extra, ...   NaN         NaN
#
#   Unnamed: 28 Unnamed: 29
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 30 columns]

# %%
guidelines_df.describe
# Out:
# <bound method NDFrame.describe of        #         BJCP Categories                    Styles    Style Family  \
# 0    01A  Standard American Beer      American Light Lager      Pale Lager
# 1    01B  Standard American Beer            American Lager      Pale Lager
# 2    01C  Standard American Beer                 Cream Ale        Pale Ale
# 3    01D  Standard American Beer       American Wheat Beer      Wheat Beer
# 4    02A     International Lager  International Pale Lager      Pale Lager
# ..   ...                     ...                       ...             ...
# 113  33A               Wood Beer            Wood-Aged Beer  Specialty Beer
# 114  33B               Wood Beer  Specialty Wood-Aged Beer  Specialty Beer
# 115  34A          Specialty Beer                Clone Beer  Specialty Beer
# 116  34B          Specialty Beer          Mixed-Style Beer  Specialty Beer
# 117  34C          Specialty Beer         Experimental Beer  Specialty Beer
#
#                 Style History          Origin  \
# 0      Mass Market Pale Lager   United States
# 1      Mass Market Pale Lager   United States
# 2    Indigenous American Beer   United States
# 3                  Wheat Beer   United States
# 4      Mass Market Pale Lager   International
# ..                        ...             ...
# 113            Specialty Beer  Specialty Beer
# 114            Specialty Beer  Specialty Beer
# 115            Specialty Beer  Specialty Beer
# 116            Specialty Beer  Specialty Beer
# 117            Specialty Beer  Specialty Beer
#
#                                              ABV min  \
# 0                                                2.8
# 1                                                4.2
# 2                                                4.2
# 3                                                  4
# 4                                                4.6
# ..                                               ...
# 113  Varies with base style, typically above-average
# 114  Varies with base style, typically above-average
# 115              Vary depending on the declared beer
# 116              Vary depending on the declared beer
# 117              Vary depending on the declared beer
#
#                                              ABV max  \
# 0                                                4.2
# 1                                                5.3
# 2                                                5.6
# 3                                                5.5
# 4                                                  6
# ..                                               ...
# 113  Varies with base style, typically above-average
# 114  Varies with base style, typically above-average
# 115              Vary depending on the declared beer
# 116              Vary depending on the declared beer
# 117              Vary depending on the declared beer
#
#                                 IBUs min                             IBUs max  \
# 0                                      8                                   12
# 1                                      8                                   18
# 2                                      8                                   20
# 3                                     15                                   30
# 4                                     18                                   25
# ..                                   ...                                  ...
# 113               Varies with base style               Varies with base style
# 114              Varies with base style               Varies with base style
# 115  Vary depending on the declared beer  Vary depending on the declared beer
# 116  Vary depending on the declared beer  Vary depending on the declared beer
# 117  Vary depending on the declared beer  Vary depending on the declared beer
#
#      ...                                          Mouthfeel  \
# 0    ...  Very light (sometimes watery) body. Very highl...
# 1    ...  Low to medium-low body. Very highly carbonated...
# 2    ...  Generally light and crisp, although body can r...
# 3    ...  Medium-light to medium body. Medium-high to hi...
# 4    ...  Light to medium body. Moderately high to highl...
# ..   ...                                                ...
# 113  ...  Varies with base style. Wood can add tannins t...
# 114  ...  Varies with base style. Wood can add tannins t...
# 115  ...                      Based on declared clone beer.
# 116  ...                 Based on the declared base styles.
# 117  ...                                            Varies.
#
#                                               Comments  \
# 0    Designed to appeal to as broad a range of the ...
# 1    Strong flavors are a fault. Often what non-cra...
# 2    Pre-prohibition Cream Ales were slightly stron...
# 3    Different variations exist, from an easy-drink...
# 4    International lagers tend to have fewer adjunc...
# ..                                                 ...
# 113  The base beer style should be apparent. The wo...
# 114  The base beer style should be apparent. The wo...
# 115  Intended as a catch-all location for specific ...
# 116  Intended for Specialty-Type combinations of st...
# 117  This style is the ultimate in creativity, sinc...
#
#                                                History  \
# 0    Coors briefly made a light lager in the early ...
# 1    Although German immigrants had brewed traditio...
# 2    A sparkling or present-use ale that existed in...
# 3    An American craft beer adaptation of the Germa...
# 4    In the United States, developed as a premium v...
# ..                                                 ...
# 113  A traditional production method that is rarely...
# 114  A traditional production method that is rarely...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                             Characteristic Ingredients  \
# 0    Two- or six-row barley with high percentage (u...
# 1    Two- or six-row barley with high percentage (u...
# 2    American ingredients most commonly used. A gra...
# 3    Clean American ale or lager yeast (German weis...
# 4    Two- or six-row barley. May use rice, corn, or...
# ..                                                 ...
# 113  Varies with base style. Aged in wooden casks o...
# 114  Varies with base style. Aged in wooden casks o...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                       Style Comparison  \
# 0    A lighter-bodied, lower-alcohol, lower calorie...
# 1    Stronger, more flavor and body than a Light Am...
# 2    Similar to a Standard American Lager, but with...
# 3    More hop character and less yeast character th...
# 4    Generally more bitter and filling than America...
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                    Commercial Examples  \
# 0    Bud Light, Coors Light, Keystone Light, Michel...
# 1    Budweiser, Coors Original, Grain Belt Premium ...
# 2    Genesee Cream Ale, Liebotschaner Cream Ale, Li...
# 3    Bell’s Oberon, Boulevard Unfiltered Wheat Beer...
# 4    Asahi Super Dry, Birra Moretti, Corona Extra, ...
# ..                                                 ...
# 113  Bush Prestige, Cigar City Humidor India Pale A...
# 114  Founders Kentucky Breakfast Stout, Goose Islan...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                                  Notes Unnamed: 27  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 113  This style is intended for beer aged in wood w...         NaN
# 114  This style is intended for beer aged in wood w...         NaN
# 115  This style is intended for reproductions of sp...         NaN
# 116  This style is intended for combinations of exi...         NaN
# 117  This is explicitly a catch-all category for an...         NaN
#
#     Unnamed: 28 Unnamed: 29
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 113         NaN         NaN
# 114         NaN         NaN
# 115         NaN         NaN
# 116         NaN         NaN
# 117         NaN         NaN
#
# [118 rows x 30 columns]>

# %%
# Drop columns we don't need
guidelines_df.drop(columns=["BJCP Categories", "Style History"], inplace=True)
guidelines_df.head()
# Out:
#      #                    Styles Style Family         Origin ABV min ABV max  \
# 0  01A      American Light Lager   Pale Lager  United States     2.8     4.2
# 1  01B            American Lager   Pale Lager  United States     4.2     5.3
# 2  01C                 Cream Ale     Pale Ale  United States     4.2     5.6
# 3  01D       American Wheat Beer   Wheat Beer  United States       4     5.5
# 4  02A  International Pale Lager   Pale Lager  International     4.6       6
#
#   IBUs min IBUs max SRM min SRM max  ...  \
# 0        8       12       2       3  ...
# 1        8       18       2       4  ...
# 2        8       20     2.5       5  ...
# 3       15       30       3       6  ...
# 4       18       25       2       6  ...
#
#                                            Mouthfeel  \
# 0  Very light (sometimes watery) body. Very highl...
# 1  Low to medium-low body. Very highly carbonated...
# 2  Generally light and crisp, although body can r...
# 3  Medium-light to medium body. Medium-high to hi...
# 4  Light to medium body. Moderately high to highl...
#
#                                             Comments  \
# 0  Designed to appeal to as broad a range of the ...
# 1  Strong flavors are a fault. Often what non-cra...
# 2  Pre-prohibition Cream Ales were slightly stron...
# 3  Different variations exist, from an easy-drink...
# 4  International lagers tend to have fewer adjunc...
#
#                                              History  \
# 0  Coors briefly made a light lager in the early ...
# 1  Although German immigrants had brewed traditio...
# 2  A sparkling or present-use ale that existed in...
# 3  An American craft beer adaptation of the Germa...
# 4  In the United States, developed as a premium v...
#
#                           Characteristic Ingredients  \
# 0  Two- or six-row barley with high percentage (u...
# 1  Two- or six-row barley with high percentage (u...
# 2  American ingredients most commonly used. A gra...
# 3  Clean American ale or lager yeast (German weis...
# 4  Two- or six-row barley. May use rice, corn, or...
#
#                                     Style Comparison  \
# 0  A lighter-bodied, lower-alcohol, lower calorie...
# 1  Stronger, more flavor and body than a Light Am...
# 2  Similar to a Standard American Lager, but with...
# 3  More hop character and less yeast character th...
# 4  Generally more bitter and filling than America...
#
#                                  Commercial Examples Notes Unnamed: 27  \
# 0  Bud Light, Coors Light, Keystone Light, Michel...   NaN         NaN
# 1  Budweiser, Coors Original, Grain Belt Premium ...   NaN         NaN
# 2  Genesee Cream Ale, Liebotschaner Cream Ale, Li...   NaN         NaN
# 3  Bell’s Oberon, Boulevard Unfiltered Wheat Beer...   NaN         NaN
# 4  Asahi Super Dry, Birra Moretti, Corona Extra, ...   NaN         NaN
#
#   Unnamed: 28 Unnamed: 29
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 28 columns]

# %%
new_guidelines_df = guidelines_df

# %%
# Drop the null columns where all values are null
new_guidelines_df.dropna(axis='columns', how='all')
new_guidelines_df.describe
# Out:
# <bound method NDFrame.describe of        #                    Styles    Style Family          Origin  \
# 0    01A      American Light Lager      Pale Lager   United States
# 1    01B            American Lager      Pale Lager   United States
# 2    01C                 Cream Ale        Pale Ale   United States
# 3    01D       American Wheat Beer      Wheat Beer   United States
# 4    02A  International Pale Lager      Pale Lager   International
# ..   ...                       ...             ...             ...
# 113  33A            Wood-Aged Beer  Specialty Beer  Specialty Beer
# 114  33B  Specialty Wood-Aged Beer  Specialty Beer  Specialty Beer
# 115  34A                Clone Beer  Specialty Beer  Specialty Beer
# 116  34B          Mixed-Style Beer  Specialty Beer  Specialty Beer
# 117  34C         Experimental Beer  Specialty Beer  Specialty Beer
#
#                                              ABV min  \
# 0                                                2.8
# 1                                                4.2
# 2                                                4.2
# 3                                                  4
# 4                                                4.6
# ..                                               ...
# 113  Varies with base style, typically above-average
# 114  Varies with base style, typically above-average
# 115              Vary depending on the declared beer
# 116              Vary depending on the declared beer
# 117              Vary depending on the declared beer
#
#                                              ABV max  \
# 0                                                4.2
# 1                                                5.3
# 2                                                5.6
# 3                                                5.5
# 4                                                  6
# ..                                               ...
# 113  Varies with base style, typically above-average
# 114  Varies with base style, typically above-average
# 115              Vary depending on the declared beer
# 116              Vary depending on the declared beer
# 117              Vary depending on the declared beer
#
#                                 IBUs min                             IBUs max  \
# 0                                      8                                   12
# 1                                      8                                   18
# 2                                      8                                   20
# 3                                     15                                   30
# 4                                     18                                   25
# ..                                   ...                                  ...
# 113               Varies with base style               Varies with base style
# 114              Varies with base style               Varies with base style
# 115  Vary depending on the declared beer  Vary depending on the declared beer
# 116  Vary depending on the declared beer  Vary depending on the declared beer
# 117  Vary depending on the declared beer  Vary depending on the declared beer
#
#                                                SRM min  \
# 0                                                    2
# 1                                                    2
# 2                                                  2.5
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 113  Varies with base style, often darker than the ...
# 114                             Varies with base style
# 115                Vary depending on the declared beer
# 116                Vary depending on the declared beer
# 117                Vary depending on the declared beer
#
#                                                SRM max  ...  \
# 0                                                    3  ...
# 1                                                    4  ...
# 2                                                    5  ...
# 3                                                    6  ...
# 4                                                    6  ...
# ..                                                 ...  ...
# 113  Varies with base style, often darker than the ...  ...
# 114                             Varies with base style  ...
# 115                Vary depending on the declared beer  ...
# 116                Vary depending on the declared beer  ...
# 117                Vary depending on the declared beer  ...
#
#                                              Mouthfeel  \
# 0    Very light (sometimes watery) body. Very highl...
# 1    Low to medium-low body. Very highly carbonated...
# 2    Generally light and crisp, although body can r...
# 3    Medium-light to medium body. Medium-high to hi...
# 4    Light to medium body. Moderately high to highl...
# ..                                                 ...
# 113  Varies with base style. Wood can add tannins t...
# 114  Varies with base style. Wood can add tannins t...
# 115                      Based on declared clone beer.
# 116                 Based on the declared base styles.
# 117                                            Varies.
#
#                                               Comments  \
# 0    Designed to appeal to as broad a range of the ...
# 1    Strong flavors are a fault. Often what non-cra...
# 2    Pre-prohibition Cream Ales were slightly stron...
# 3    Different variations exist, from an easy-drink...
# 4    International lagers tend to have fewer adjunc...
# ..                                                 ...
# 113  The base beer style should be apparent. The wo...
# 114  The base beer style should be apparent. The wo...
# 115  Intended as a catch-all location for specific ...
# 116  Intended for Specialty-Type combinations of st...
# 117  This style is the ultimate in creativity, sinc...
#
#                                                History  \
# 0    Coors briefly made a light lager in the early ...
# 1    Although German immigrants had brewed traditio...
# 2    A sparkling or present-use ale that existed in...
# 3    An American craft beer adaptation of the Germa...
# 4    In the United States, developed as a premium v...
# ..                                                 ...
# 113  A traditional production method that is rarely...
# 114  A traditional production method that is rarely...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                             Characteristic Ingredients  \
# 0    Two- or six-row barley with high percentage (u...
# 1    Two- or six-row barley with high percentage (u...
# 2    American ingredients most commonly used. A gra...
# 3    Clean American ale or lager yeast (German weis...
# 4    Two- or six-row barley. May use rice, corn, or...
# ..                                                 ...
# 113  Varies with base style. Aged in wooden casks o...
# 114  Varies with base style. Aged in wooden casks o...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                       Style Comparison  \
# 0    A lighter-bodied, lower-alcohol, lower calorie...
# 1    Stronger, more flavor and body than a Light Am...
# 2    Similar to a Standard American Lager, but with...
# 3    More hop character and less yeast character th...
# 4    Generally more bitter and filling than America...
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                    Commercial Examples  \
# 0    Bud Light, Coors Light, Keystone Light, Michel...
# 1    Budweiser, Coors Original, Grain Belt Premium ...
# 2    Genesee Cream Ale, Liebotschaner Cream Ale, Li...
# 3    Bell’s Oberon, Boulevard Unfiltered Wheat Beer...
# 4    Asahi Super Dry, Birra Moretti, Corona Extra, ...
# ..                                                 ...
# 113  Bush Prestige, Cigar City Humidor India Pale A...
# 114  Founders Kentucky Breakfast Stout, Goose Islan...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                                  Notes Unnamed: 27  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 113  This style is intended for beer aged in wood w...         NaN
# 114  This style is intended for beer aged in wood w...         NaN
# 115  This style is intended for reproductions of sp...         NaN
# 116  This style is intended for combinations of exi...         NaN
# 117  This is explicitly a catch-all category for an...         NaN
#
#     Unnamed: 28 Unnamed: 29
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 113         NaN         NaN
# 114         NaN         NaN
# 115         NaN         NaN
# 116         NaN         NaN
# 117         NaN         NaN
#
# [118 rows x 28 columns]>

# %%
# Drop the null rows
new_guidelines_df.dropna()
new_guidelines_df.describe
# Out:
# <bound method NDFrame.describe of        #                    Styles    Style Family          Origin  \
# 0    01A      American Light Lager      Pale Lager   United States
# 1    01B            American Lager      Pale Lager   United States
# 2    01C                 Cream Ale        Pale Ale   United States
# 3    01D       American Wheat Beer      Wheat Beer   United States
# 4    02A  International Pale Lager      Pale Lager   International
# ..   ...                       ...             ...             ...
# 113  33A            Wood-Aged Beer  Specialty Beer  Specialty Beer
# 114  33B  Specialty Wood-Aged Beer  Specialty Beer  Specialty Beer
# 115  34A                Clone Beer  Specialty Beer  Specialty Beer
# 116  34B          Mixed-Style Beer  Specialty Beer  Specialty Beer
# 117  34C         Experimental Beer  Specialty Beer  Specialty Beer
#
#                                              ABV min  \
# 0                                                2.8
# 1                                                4.2
# 2                                                4.2
# 3                                                  4
# 4                                                4.6
# ..                                               ...
# 113  Varies with base style, typically above-average
# 114  Varies with base style, typically above-average
# 115              Vary depending on the declared beer
# 116              Vary depending on the declared beer
# 117              Vary depending on the declared beer
#
#                                              ABV max  \
# 0                                                4.2
# 1                                                5.3
# 2                                                5.6
# 3                                                5.5
# 4                                                  6
# ..                                               ...
# 113  Varies with base style, typically above-average
# 114  Varies with base style, typically above-average
# 115              Vary depending on the declared beer
# 116              Vary depending on the declared beer
# 117              Vary depending on the declared beer
#
#                                 IBUs min                             IBUs max  \
# 0                                      8                                   12
# 1                                      8                                   18
# 2                                      8                                   20
# 3                                     15                                   30
# 4                                     18                                   25
# ..                                   ...                                  ...
# 113               Varies with base style               Varies with base style
# 114              Varies with base style               Varies with base style
# 115  Vary depending on the declared beer  Vary depending on the declared beer
# 116  Vary depending on the declared beer  Vary depending on the declared beer
# 117  Vary depending on the declared beer  Vary depending on the declared beer
#
#                                                SRM min  \
# 0                                                    2
# 1                                                    2
# 2                                                  2.5
# 3                                                    3
# 4                                                    2
# ..                                                 ...
# 113  Varies with base style, often darker than the ...
# 114                             Varies with base style
# 115                Vary depending on the declared beer
# 116                Vary depending on the declared beer
# 117                Vary depending on the declared beer
#
#                                                SRM max  ...  \
# 0                                                    3  ...
# 1                                                    4  ...
# 2                                                    5  ...
# 3                                                    6  ...
# 4                                                    6  ...
# ..                                                 ...  ...
# 113  Varies with base style, often darker than the ...  ...
# 114                             Varies with base style  ...
# 115                Vary depending on the declared beer  ...
# 116                Vary depending on the declared beer  ...
# 117                Vary depending on the declared beer  ...
#
#                                              Mouthfeel  \
# 0    Very light (sometimes watery) body. Very highl...
# 1    Low to medium-low body. Very highly carbonated...
# 2    Generally light and crisp, although body can r...
# 3    Medium-light to medium body. Medium-high to hi...
# 4    Light to medium body. Moderately high to highl...
# ..                                                 ...
# 113  Varies with base style. Wood can add tannins t...
# 114  Varies with base style. Wood can add tannins t...
# 115                      Based on declared clone beer.
# 116                 Based on the declared base styles.
# 117                                            Varies.
#
#                                               Comments  \
# 0    Designed to appeal to as broad a range of the ...
# 1    Strong flavors are a fault. Often what non-cra...
# 2    Pre-prohibition Cream Ales were slightly stron...
# 3    Different variations exist, from an easy-drink...
# 4    International lagers tend to have fewer adjunc...
# ..                                                 ...
# 113  The base beer style should be apparent. The wo...
# 114  The base beer style should be apparent. The wo...
# 115  Intended as a catch-all location for specific ...
# 116  Intended for Specialty-Type combinations of st...
# 117  This style is the ultimate in creativity, sinc...
#
#                                                History  \
# 0    Coors briefly made a light lager in the early ...
# 1    Although German immigrants had brewed traditio...
# 2    A sparkling or present-use ale that existed in...
# 3    An American craft beer adaptation of the Germa...
# 4    In the United States, developed as a premium v...
# ..                                                 ...
# 113  A traditional production method that is rarely...
# 114  A traditional production method that is rarely...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                             Characteristic Ingredients  \
# 0    Two- or six-row barley with high percentage (u...
# 1    Two- or six-row barley with high percentage (u...
# 2    American ingredients most commonly used. A gra...
# 3    Clean American ale or lager yeast (German weis...
# 4    Two- or six-row barley. May use rice, corn, or...
# ..                                                 ...
# 113  Varies with base style. Aged in wooden casks o...
# 114  Varies with base style. Aged in wooden casks o...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                       Style Comparison  \
# 0    A lighter-bodied, lower-alcohol, lower calorie...
# 1    Stronger, more flavor and body than a Light Am...
# 2    Similar to a Standard American Lager, but with...
# 3    More hop character and less yeast character th...
# 4    Generally more bitter and filling than America...
# ..                                                 ...
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                    Commercial Examples  \
# 0    Bud Light, Coors Light, Keystone Light, Michel...
# 1    Budweiser, Coors Original, Grain Belt Premium ...
# 2    Genesee Cream Ale, Liebotschaner Cream Ale, Li...
# 3    Bell’s Oberon, Boulevard Unfiltered Wheat Beer...
# 4    Asahi Super Dry, Birra Moretti, Corona Extra, ...
# ..                                                 ...
# 113  Bush Prestige, Cigar City Humidor India Pale A...
# 114  Founders Kentucky Breakfast Stout, Goose Islan...
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
#
#                                                  Notes Unnamed: 27  \
# 0                                                  NaN         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3                                                  NaN         NaN
# 4                                                  NaN         NaN
# ..                                                 ...         ...
# 113  This style is intended for beer aged in wood w...         NaN
# 114  This style is intended for beer aged in wood w...         NaN
# 115  This style is intended for reproductions of sp...         NaN
# 116  This style is intended for combinations of exi...         NaN
# 117  This is explicitly a catch-all category for an...         NaN
#
#     Unnamed: 28 Unnamed: 29
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 113         NaN         NaN
# 114         NaN         NaN
# 115         NaN         NaN
# 116         NaN         NaN
# 117         NaN         NaN
#
# [118 rows x 28 columns]>

# %%
# Compare column "Style" in recipeData.csv to column "Styles" in guidelines.csv. We only want to use beer styles that are in guidelines.csv
# Remove any beers styles in recipeData.csv that isn't in guidelines.csv

# %%
# Find out how often each of our styles of beer occurs in the recipeData.csv and remove any styles that are outliers by lack of occurance.
